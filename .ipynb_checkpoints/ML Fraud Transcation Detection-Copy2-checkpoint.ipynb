# %% [markdown]
# <h2 style="color:Red",align="center" >ML Project-Fraud Transcation Detection</h2>

# %% [markdown]
# # Import all required libraries

# %%
import numpy as np
import pandas as pd
import sklearn
import scipy
import matplotlib.pyplot as plt
import seaborn as sns 
from  plotly.offline import iplot
import plotly as py 
import plotly.tools as tls 
import cufflinks as cf 
# %matplotlib inline
from sklearn.metrics import classification_report,accuracy_score
from sklearn.ensemble import IsolationForest
from sklearn.neighbors import LocalOutlierFactor
from sklearn.svm import OneClassSVM
from pylab import rcParams
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import normalize
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix 
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install cassandra-driver
# Out:
# Requirement already satisfied: cassandra-driver in c:\users\welcome\anaconda3\lib\site-packages (3.25.0)
# Requirement already satisfied: geomet<0.3,>=0.1 in c:\users\welcome\anaconda3\lib\site-packages (from cassandra-driver) (0.2.1.post1)
# Requirement already satisfied: six>=1.9 in c:\users\welcome\anaconda3\lib\site-packages (from cassandra-driver) (1.14.0)
# Requirement already satisfied: click in c:\users\welcome\anaconda3\lib\site-packages (from geomet<0.3,>=0.1->cassandra-driver) (7.0)

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

cloud_config= {
        'secure_connect_bundle': r'C:\Users\welcome\Desktop\secure-connect-fraud-detection-project.zip'
}
auth_provider = PlainTextAuthProvider('sucxMwwdJsamJapdFOdcUsgy', 'KB9lDaTEf_v,12OInbgmPo6zr+b1hOdyOoorlbjNbM3ZD0C_TZqIdAmZ.a8Lq+6RWlk83Fj_,nMvNZX4s7ZdCZx_BCZ68oLoOeZMOH,vl_ZJa24GUB0d9-3ng8tEmXA5')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()
session.set_keyspace("ML_Project")
session.default_fetch_size=None

count=0
results = session.execute("SELECT * FROM creditcard",timeout=None)
for i in results:
    count+=1
    data=pd.DataFrame(results)

# %%
data
# Out:
#        Class   Time            V1            V2            V3           V4  \
# 0          1    406  -2.312226542   1.951992011  -1.609850732  3.997905588
# 1          1    472  -3.043540624  -3.157307121    1.08846278  2.288643618
# 2          1   4462  -2.303349568    1.75924746  -0.359744743  2.330243051
# 3          1   6986  -4.397974442   1.358367028  -2.592844218  2.679786967
# 4          1   7519   1.234235046   3.019740421  -4.304596885   4.73279513
# ...      ...    ...           ...           ...           ...          ...
# 52368      0  45549   1.035919196  -0.004393342   1.312297617  1.310594361
# 52369      0  45551  -1.984123748   0.193889487   0.560990485  -0.56271154
# 52370      0  45551   1.112010105  -0.369666273   0.770240434  0.181258556
# 52371      0  45552  -0.810731885   0.405718467   1.166004412  0.174884784
# 52372      0  45553  -1.449981174   0.971473103   0.725380787  0.608057747
#
#                  V5            V6            V7            V8  ...  \
# 0      -0.522187865  -1.426545319  -2.537387306   1.391657248  ...
# 1        1.35980513  -1.064822523   0.325574266  -0.067793653  ...
# 2      -0.821628328  -0.075787571   0.562319782  -0.399146578  ...
# 3      -1.128130942  -1.706536388  -3.496197293  -0.248777743  ...
# 4       3.624200831  -1.357745663   1.713444988  -0.496358487  ...
# ...             ...           ...           ...           ...  ...
# 52368  -0.874263824  -0.129115385  -0.490823823   0.102838286  ...
# 52369   0.421505708  -0.089439445   0.974425228   0.323494746  ...
# 52370  -1.073855755   -0.67908459  -0.456284711   0.117849059  ...
# 52371   0.719211603   0.129013301   0.563286914   0.251766252  ...
# 52372   0.564587257  -0.048967446   0.348578872   0.157750019  ...
# 49830  -0.013236964  -0.216632476   0.110850612   0.363081185   0.152848544
# 35014   0.417058407  -0.310674225  -0.931174296    0.03505348    0.14379031
# ...             ...           ...           ...           ...           ...
# 11284  -1.398297132   0.398435074   0.490810518   0.029415678   -0.04382032
# 44732   0.349256001   0.131794161  -0.385884171   0.182827193   0.079187631
# 38158  -0.207367446  -0.230648411   0.903833656  -0.095279231   0.079634055
# 860     0.130487916   0.482469027    0.39414256  -0.409756222  -0.179563892
# 15795  -0.948294745   0.569212287   0.259382493  -0.087804183  -0.083907868
#
#        Amount
# 20570   32.21
# 8467     7.58
# 50003   44.99
# 49830    5.99
# 35014  223.49
# ...       ...
# 11284   18.66
# 44732      24
# 38158   482.9
# 860     35.64
# 15795   45.61
#
# [36661 rows x 30 columns]

# %%
scaler = StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler
X_train = scaler.fit_transform(x_train)
X_test= scaler.transform(x_test)

# %%
(pd.DataFrame(X_train)).head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.103583 -0.858282  0.915933  1.338260  1.691037  0.017371  1.677622
# 1 -1.404397 -0.226306  0.050534  0.757543 -0.075895  0.465210 -0.311976
# 2  1.108574 -0.496805  1.245358 -2.565277  1.161099  0.067854 -1.558079
# 3  1.103121 -0.209465  0.690756  0.294972 -0.146018  0.232112 -0.502842
# 4  0.621491 -0.333653  0.322316  0.452701  0.330945 -0.059590 -0.325684
#
#          7         8         9   ...        20        21        22        23  \
# 0 -0.209865 -1.234877 -0.022283  ... -0.231206  2.064492  0.055280  0.164069
# 1 -0.177142  0.099907  0.585033  ...  0.200651 -0.011018  0.119056  0.312347
# 2 -0.104628  0.918652 -0.568323  ... -0.092578 -0.006757 -0.192096  0.232640
# 3  0.515667  0.071501 -0.107964  ...  0.114139 -0.351821 -0.923088  0.163805
# 4  1.375794 -0.107541 -1.043025  ...  0.492660 -0.206632 -1.471289  1.056962
#
#          24        25        26        27        28        29
# 0 -0.566803 -0.836706  0.244967 -2.634307 -2.163823 -0.245377
# 1 -0.008336 -2.270226  1.841064  0.100670  0.380764 -0.341562
# 2  0.284693 -1.262680 -0.879046  0.410381 -0.563087 -0.195468
# 3 -0.038903 -0.801463  0.180732  0.931930  0.437193 -0.347772
# 4  0.685843 -1.015862 -1.901366  0.075081  0.410419  0.501614
#
# [5 rows x 30 columns]

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (36661, 30)
# (15712, 30)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (36661,)
# (15712,)

# %%
# !pip install --user imblearn
# Out:
# Requirement already satisfied: imblearn in c:\users\welcome\appdata\roaming\python\python38\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\welcome\appdata\roaming\python\python38\site-packages (from imblearn) (0.8.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\welcome\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.7.1)
# Requirement already satisfied: scikit-learn>=0.24 in c:\users\welcome\appdata\roaming\python\python38\site-packages (from imbalanced-learn->imblearn) (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\welcome\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.18.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\welcome\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (0.14.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\welcome\anaconda3\lib\site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)

# %%
print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 0    36548
# 1      113
# Name: Class, dtype: int64
# 0    15672
# 1       40
# Name: Class, dtype: int64

# %%
from collections import Counter 
Counter(y_train)
# Out:
# Counter({0: 36548, 1: 113})

# %%
from imblearn.under_sampling import NearMiss
nm=NearMiss()
nm
# Out:
# NearMiss()

# %% [markdown]
# ### Under Sampling

# %%
from imblearn.under_sampling import NearMiss
nm=NearMiss(0.7)
nm
# Out:
# NearMiss(sampling_strategy=0.7)

# %%
X_nm,Y_nm=nm.fit_resample(X_train,y_train)

# %%
print("The Number of classes Before the fit {}".format(Counter(y_train)))
print("The Number of classes After the fit {}".format(Counter(Y_nm)))
# Out:
# The Number of classes Before the fit Counter({0: 36548, 1: 113})
# The Number of classes After the fit Counter({0: 161, 1: 113})

# %% [markdown]
# ### Logistic Regression

# %%
# Preparing Classification Models
from sklearn.linear_model import LogisticRegression

# %%
classifier_regressor = LogisticRegression(random_state = 42)

# %%
classifier_regressor.fit(X_nm,Y_nm)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_regressor_log = classifier_regressor.predict(X_test)
y_pred_regressor_log
# Out:
# array([1, 0, 0, ..., 1, 0, 1], dtype=int64)

# %%
log_Accuracy = classifier_regressor.score(X_test,y_test)
log_Accuracy
# Out:
# 0.6179989816700611

# %%
cm_regressor_Log = confusion_matrix(y_test, y_pred_regressor_log)
print(cm_regressor_Log)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_log))
print(classification_report(y_test, y_pred_regressor_log))
# Out:
# [[9673 5999]
#  [   3   37]]
# Accuracy score of the model: 0.6179989816700611
#               precision    recall  f1-score   support
#
#            0       1.00      0.62      0.76     15672
#            1       0.01      0.93      0.01        40
#
#     accuracy                           0.62     15712
#    macro avg       0.50      0.77      0.39     15712
# weighted avg       1.00      0.62      0.76     15712

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=20,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
rf
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
rf.fit(X_nm,Y_nm)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_pred_regressor_rf = rf.predict(X_test)
y_pred_regressor_rf
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
RF_Accuracy = rf.score(X_test,y_test)
RF_Accuracy
# Out:
# 0.49376272912423624

# %%
cm_regressor_rf = confusion_matrix(y_test, y_pred_regressor_rf)
print(cm_regressor_rf)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_rf))
print(classification_report(y_test, y_pred_regressor_rf))
# Out:
# [[7719 7953]
#  [   1   39]]
# Accuracy score of the model: 0.49376272912423624
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.66     15672
#            1       0.00      0.97      0.01        40
#
#     accuracy                           0.49     15712
#    macro avg       0.50      0.73      0.33     15712
# weighted avg       1.00      0.49      0.66     15712

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC

# %%
svm = SVC(kernel = 'linear', random_state=0,gamma="scale")
svm.fit(X_nm,Y_nm)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred_regressor_svm = rf.predict(X_test)
y_pred_regressor_svm
# Out:
# array([1, 0, 0, ..., 1, 1, 1], dtype=int64)

# %%
SVM_Accuracy = svm.score(X_test,y_test)
SVM_Accuracy
# Out:
# 0.6279276985743381

# %%
cm_regressor_svm = confusion_matrix(y_test, y_pred_regressor_svm)
print(cm_regressor_svm)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_svm))
print(classification_report(y_test, y_pred_regressor_svm))
# Out:
# [[7719 7953]
#  [   1   39]]
# Accuracy score of the model: 0.49376272912423624
#               precision    recall  f1-score   support
#
#            0       1.00      0.49      0.66     15672
#            1       0.00      0.97      0.01        40
#
#     accuracy                           0.49     15712
#    macro avg       0.50      0.73      0.33     15712
# weighted avg       1.00      0.49      0.66     15712

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import StratifiedKFold
skfold=StratifiedKFold(n_splits=10)

# %%
dt = DecisionTreeClassifier(criterion = 'entropy', random_state = 21,ccp_alpha=0.15)
dt.fit(X_nm,Y_nm)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.15, criterion='entropy', random_state=21)

# %%
y_pred_regressor_dt = dt.predict(X_test)
y_pred_regressor_dt
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
DTree_Accuracy = dt.score(X_test,y_test)
DTree_Accuracy
# Out:
# 0.436290733197556

# %%
cm_regressor_dt = confusion_matrix(y_test, y_pred_regressor_dt)
print(cm_regressor_dt)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_dt))
print(classification_report(y_test, y_pred_regressor_dt))
# Out:
# [[6818 8854]
#  [   3   37]]
# Accuracy score of the model: 0.436290733197556
#               precision    recall  f1-score   support
#
#            0       1.00      0.44      0.61     15672
#            1       0.00      0.93      0.01        40
#
#     accuracy                           0.44     15712
#    macro avg       0.50      0.68      0.31     15712
# weighted avg       1.00      0.44      0.60     15712

# %% [raw]
# from sklearn import tree
# plt.figure(figsize=(15,10))
# tree.plot_tree(dt,filled=True)

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 10, metric='minkowski', p=2)
knn.fit(X_nm,Y_nm)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred_regressor_knn = knn.predict(X_test)
y_pred_regressor_knn
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Knn_Accuracy = knn.score(X_test,y_test)
Knn_Accuracy
# Out:
# 0.9992998981670062

# %%
cm_regressor_knn = confusion_matrix(y_test, y_pred_regressor_knn)
print(cm_regressor_knn)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_knn))
print(classification_report(y_test, y_pred_regressor_knn))
# Out:
# [[15665     7]
#  [    4    36]]
# Accuracy score of the model: 0.9992998981670062
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       0.84      0.90      0.87        40
#
#     accuracy                           1.00     15712
#    macro avg       0.92      0.95      0.93     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### XGboost

# %%
! pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\welcome\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy in c:\users\welcome\anaconda3\lib\site-packages (from xgboost) (1.18.1)
# Requirement already satisfied: scipy in c:\users\welcome\anaconda3\lib\site-packages (from xgboost) (1.7.1)

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score

# %%
xgb=xgb.XGBClassifier(base_score=0.5, booster='gbtree',gamma=0.0,
              learning_rate=0.05, max_delta_step=0, max_depth=4,
              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,validate_parameters=1, verbosity=None)

# %%
xgb.fit(X_nm,Y_nm)
# Out:
# [18:21:57] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_regressor_xgb = xgb.predict(X_test)
y_pred_regressor_xgb
# Out:
# array([1, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
xgb_Accuracy = xgb.score(X_test,y_test)
xgb_Accuracy
# Out:
# 0.4279531568228106

# %%
cm_regressor_xgb = confusion_matrix(y_test, y_pred_regressor_xgb)
print(cm_regressor_xgb)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_xgb))
print(classification_report(y_test, y_pred_regressor_xgb))
# Out:
# [[6685 8987]
#  [   1   39]]
# Accuracy score of the model: 0.4279531568228106
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60     15672
#            1       0.00      0.97      0.01        40
#
#     accuracy                           0.43     15712
#    macro avg       0.50      0.70      0.30     15712
# weighted avg       1.00      0.43      0.60     15712

# %% [markdown]
# ### Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(X_nm,Y_nm)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb.predict(X_test)
y_pred_nb
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
NB_Accuracy = nb.score(X_test,y_test)
NB_Accuracy
# Out:
# 0.8125

# %%
cm_regressor_nb = confusion_matrix(y_test, y_pred_nb)
print(cm_regressor_nb)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))
# Out:
# [[12730  2942]
#  [    4    36]]
# Accuracy score of the model: 0.8125
#               precision    recall  f1-score   support
#
#            0       1.00      0.81      0.90     15672
#            1       0.01      0.90      0.02        40
#
#     accuracy                           0.81     15712
#    macro avg       0.51      0.86      0.46     15712
# weighted avg       1.00      0.81      0.89     15712

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique) – Oversampling

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(0.7,random_state = 42)
X_train_Smote, Y_train_Smote = sm.fit_resample(X_train, y_train)

# %%
print("The Number of classes Before the fit {}".format(Counter(y_train)))
print("The Number of classes After the fit {}".format(Counter(Y_train_Smote)))
# Out:
# The Number of classes Before the fit Counter({0: 36548, 1: 113})
# The Number of classes After the fit Counter({0: 36548, 1: 25583})

# %% [markdown]
# #### Logistic Regression

# %%
classifier_regressor_Smote = LogisticRegression(random_state = 42)
classifier_regressor_Smote.fit(X_train_Smote, Y_train_Smote)
# Out:
# LogisticRegression(random_state=42)

# %%
y_pred_regressor_log_SMOTE = classifier_regressor_Smote.predict(X_test)
y_pred_regressor_log_SMOTE
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
log_Accuracy_SMOTE = classifier_regressor_Smote.score(X_test,y_test)
log_Accuracy_SMOTE
# Out:
# 0.9903895112016293

# %%
cm_regressor_Log_SMOTE = confusion_matrix(y_test, y_pred_regressor_log_SMOTE)
print(cm_regressor_Log_SMOTE)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_log_SMOTE))
print(classification_report(y_test, y_pred_regressor_log_SMOTE))
# Out:
# [[15524   148]
#  [    3    37]]
# Accuracy score of the model: 0.9903895112016293
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     15672
#            1       0.20      0.93      0.33        40
#
#     accuracy                           0.99     15712
#    macro avg       0.60      0.96      0.66     15712
# weighted avg       1.00      0.99      0.99     15712

# %% [markdown]
# ### RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
rf_SMOTE = RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
                       criterion='gini', max_depth=None, max_features='auto',
                       max_leaf_nodes=None, max_samples=None,
                       min_impurity_decrease=0.0, min_impurity_split=None,
                       min_samples_leaf=1, min_samples_split=2,
                       min_weight_fraction_leaf=0.0, n_estimators=20,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)
rf_SMOTE
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
rf_SMOTE.fit(X_train_Smote, Y_train_Smote)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y_pred_regressor_rf1 = rf_SMOTE.predict(X_test)
y_pred_regressor_rf1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
RF_Accuracy_SMOTE = rf_SMOTE.score(X_test,y_test)
RF_Accuracy_SMOTE
# Out:
# 0.9995544806517311

# %%
cm_regressor_rf1 = confusion_matrix(y_test, y_pred_regressor_rf1)
print(cm_regressor_rf1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_rf1))
print(classification_report(y_test, y_pred_regressor_rf1))
# Out:
# [[15672     0]
#  [    7    33]]
# Accuracy score of the model: 0.9995544806517311
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       1.00      0.82      0.90        40
#
#     accuracy                           1.00     15712
#    macro avg       1.00      0.91      0.95     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### SVM

# %%
svm_smote = SVC(kernel = 'rbf', random_state=0,gamma="auto")
svm_smote.fit(X_train_Smote, Y_train_Smote)
# Out:
# SVC(gamma='auto', random_state=0)

# %%
y_pred_regressor_svm1 = svm_smote.predict(X_test)
y_pred_regressor_svm1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
SVM_Accuracy_SMOTE = svm_smote.score(X_test,y_test)
SVM_Accuracy_SMOTE
# Out:
# 0.9984725050916496

# %%
cm_regressor_svm1 = confusion_matrix(y_test, y_pred_regressor_svm1)
print(cm_regressor_svm1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_svm1))
print(classification_report(y_test, y_pred_regressor_svm1))
# Out:
# [[15657    15]
#  [    9    31]]
# Accuracy score of the model: 0.9984725050916496
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       0.67      0.78      0.72        40
#
#     accuracy                           1.00     15712
#    macro avg       0.84      0.89      0.86     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### Decision Tree

# %%
dt_SMOTE = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
dt_SMOTE.fit(X_train_Smote, Y_train_Smote)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred_regressor_dt1 = dt_SMOTE.predict(X_test)
y_pred_regressor_dt1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
DTree_Accuracy_SMOTE = dt_SMOTE.score(X_test,y_test)
DTree_Accuracy_SMOTE
# Out:
# 0.9978996945010183

# %%
cm_regressor_dt1 = confusion_matrix(y_test, y_pred_regressor_dt1)
print(cm_regressor_dt1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_dt1))
print(classification_report(y_test, y_pred_regressor_dt1))
# Out:
# [[15646    26]
#  [    7    33]]
# Accuracy score of the model: 0.9978996945010183
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       0.56      0.82      0.67        40
#
#     accuracy                           1.00     15712
#    macro avg       0.78      0.91      0.83     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### KNN

# %%
knn_SMOTE = KNeighborsClassifier(n_neighbors = 10, metric='minkowski', p=2)
knn_SMOTE.fit(X_train_Smote, Y_train_Smote)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
y_pred_regressor_knn1 = knn_SMOTE.predict(X_test)
y_pred_regressor_knn1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
Knn_Accuracy_SMOTE = knn_SMOTE.score(X_test,y_test)
Knn_Accuracy_SMOTE
# Out:
# 0.9967540733197556

# %%
cm_regressor_knn1 = confusion_matrix(y_test, y_pred_regressor_knn1)
print(cm_regressor_knn1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_knn1))
print(classification_report(y_test, y_pred_regressor_knn1))
# Out:
# [[15623    49]
#  [    2    38]]
# Accuracy score of the model: 0.9967540733197556
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       0.44      0.95      0.60        40
#
#     accuracy                           1.00     15712
#    macro avg       0.72      0.97      0.80     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### XGB

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score

# %%
xgb_SMOTE=xgb.XGBClassifier(base_score=0.5, booster='gbtree',gamma=0.0,
              learning_rate=0.05, max_delta_step=0, max_depth=4,
              n_estimators=100, n_jobs=4,random_state=0, verbosity=None)
xgb_SMOTE.fit(X_train_Smote, Y_train_Smote)
# Out:
# [18:25:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0.0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.05, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred_regressor_xgb1 = xgb_SMOTE.predict(X_test)
y_pred_regressor_xgb1
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
xgb_Accuracy_SMOTE = xgb_SMOTE.score(X_test,y_test)
xgb_Accuracy_SMOTE
# Out:
# 0.9982815682281059

# %%
cm_regressor_xgb1 = confusion_matrix(y_test, y_pred_regressor_xgb1)
print(cm_regressor_xgb1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_regressor_xgb1))
print(classification_report(y_test, y_pred_regressor_xgb1))
# Out:
# [[15647    25]
#  [    2    38]]
# Accuracy score of the model: 0.9982815682281059
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     15672
#            1       0.60      0.95      0.74        40
#
#     accuracy                           1.00     15712
#    macro avg       0.80      0.97      0.87     15712
# weighted avg       1.00      1.00      1.00     15712

# %% [markdown]
# ### Naive bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb_SMOTE = GaussianNB()

# %%
nb_SMOTE.fit(X_train_Smote, Y_train_Smote)
# Out:
# GaussianNB()

# %%
y_pred_nb = nb_SMOTE.predict(X_test)
y_pred_nb
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
NB_Accuracy_SMOTE= nb.score(X_test,y_test)
NB_Accuracy_SMOTE
# Out:
# 0.8125

# %%
cm_regressor_nb1 = confusion_matrix(y_test, y_pred_nb)
print(cm_regressor_nb1)
print("Accuracy score of the model:",accuracy_score(y_test, y_pred_nb))
print(classification_report(y_test, y_pred_nb))
# Out:
# [[15389   283]
#  [    3    37]]
# Accuracy score of the model: 0.9817973523421588
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     15672
#            1       0.12      0.93      0.21        40
#
#     accuracy                           0.98     15712
#    macro avg       0.56      0.95      0.60     15712
# weighted avg       1.00      0.98      0.99     15712

# %%
Accuracy = pd.DataFrame()

# %%
Accuracy['LogReg']= log_Accuracy
Accuracy['Random.F']=RF_Accuracy
Accuracy['SVM']=SVM_Accuracy
Accuracy['Decision Tree']=DTree_Accuracy
Accuracy['KNN']=Knn_Accuracy
Accuracy['XGB'] =xgb_Accuracy
Accuracy['Naive_Bayes']=NB_Accuracy

# %%
Accuracy_SMOTE = pd.DataFrame()

# %%
Accuracy_SMOTE['LogReg']= log_Accuracy_SMOTE
Accuracy_SMOTE['Random.F']=RF_Accuracy_SMOTE
Accuracy_SMOTE['SVM']=SVM_Accuracy_SMOTE
Accuracy_SMOTE['Decision Tree']=DTree_Accuracy_SMOTE
Accuracy_SMOTE['KNN']=Knn_Accuracy_SMOTE
Accuracy_SMOTE['XGB'] =xgb_Accuracy_SMOTE
Accuracy_SMOTE['Naive_Bayes']=NB_Accuracy_SMOTE

# %%
Models_Accuracy=pd.DataFrame({"Model":list(Accuracy),"Accuracy Score": [log_Accuracy,RF_Accuracy,SVM_Accuracy,DTree_Accuracy,Knn_Accuracy,xgb_Accuracy,NB_Accuracy]})
Models_Accuracy
# Out:
#            Model  Accuracy Score
# 0         LogReg        0.617999
# 1       Random.F        0.493763
# 2            SVM        0.627928
# 3  Decision Tree        0.436291
# 4            KNN        0.999300
# 5            XGB        0.427953
# 6    Naive_Bayes        0.812500

# %%
Models_Accuracy_SMOTE=pd.DataFrame({"Model":list(Accuracy_SMOTE),"Accuracy Score": [log_Accuracy_SMOTE,RF_Accuracy_SMOTE,SVM_Accuracy_SMOTE,DTree_Accuracy_SMOTE,Knn_Accuracy_SMOTE,xgb_Accuracy_SMOTE,NB_Accuracy_SMOTE]})
Models_Accuracy_SMOTE
# Out:
#            Model  Accuracy Score
# 0         LogReg        0.990390
# 1       Random.F        0.999554
# 2            SVM        0.998473
# 3  Decision Tree        0.997900
# 4            KNN        0.996754
# 5            XGB        0.998282
# 6    Naive_Bayes        0.812500

# %%
import pickle

# %%
file = open('Fraud_Detection_Model.pkl', 'wb')
pickle.dump(rf_SMOTE, file)

# %%
f = pd.read_pickle(r'Fraud_Detection_Model.pkl')
f
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
with open(r'D:\DATA SCIENTIST & AI\iNeuron\Project\ML Fraud Transcation Detection\Fraud_Detection_Model.pkl', 'rb') as f:
    x = pickle.load(f)
